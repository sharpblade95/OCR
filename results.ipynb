# %% [markdown]
# <a href="https://colab.research.google.com/github/sharpblade95/OCR/blob/master/results.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
forward_pass()
# Out:
# Total accuracy on dataset:  0.7676
# Predicted with >90% confidence:  0.3108
# Predicted wrong with >90% confidence:  0.005758157389635317
#
# Mistake samples:
# <PIL.Image.Image image mode=RGB size=140x30 at 0x7FA84020A860>
# predicted label:  1121898027 dataset label:  112189827
# <PIL.Image.Image image mode=RGB size=140x30 at 0x7FA82D7DE128>
# predicted label:  390258866 dataset label:  390251866
# <PIL.Image.Image image mode=RGB size=140x30 at 0x7FA82D7DE0F0>
# predicted label:  662755676 dataset label:  662755677
# <PIL.Image.Image image mode=RGB size=140x30 at 0x7FA82D7DE198>
# predicted label:  452185246 dataset label:  452185746
# <PIL.Image.Image image mode=RGB size=140x30 at 0x7FA82D7D3F98>
# predicted label:  892179929 dataset label:  892179919
# <PIL.Image.Image image mode=RGB size=140x30 at 0x7FA82D7D3F98>
# predicted label:  7821214943 dataset label:  782164943
# <PIL.Image.Image image mode=RGB size=140x30 at 0x7FA84020A860>
# ...

# %%
forward_pass()
# Out:
# Total accuracy on dataset:  0.7676
# Predicted with >85% confidence:  0.3837
# Predicted wrong with >85% confidence:  0.009550851832731027
#
# Mistake samples:
# <PIL.Image.Image image mode=RGB size=140x30 at 0x7FA82D137828>
# predicted label:  1121898027 dataset label:  112189827
# <PIL.Image.Image image mode=RGB size=140x30 at 0x7FA7E3C0DF98>
# predicted label:  890665699 dataset label:  892865699
# <PIL.Image.Image image mode=RGB size=140x30 at 0x7FA82D137828>
# predicted label:  460286114 dataset label:  460386111
# <PIL.Image.Image image mode=RGB size=140x30 at 0x7FA82D137400>
# predicted label:  490211538 dataset label:  390211538
# <PIL.Image.Image image mode=RGB size=140x30 at 0x7FA82D128F60>
# predicted label:  390258866 dataset label:  390251866
# <PIL.Image.Image image mode=RGB size=140x30 at 0x7FA82D67EEB8>
# predicted label:  322122368 dataset label:  122122368
# <PIL.Image.Image image mode=RGB size=140x30 at 0x7FA7E3C3AC50>
# ...

# %%
forward_pass()
# Out:
# Total accuracy on dataset:  0.7676
# Predicted with >95% confidence:  0.2008
# Predicted wrong with >95% confidence:  0.0009950248756218905
#
# Mistake samples:
# <PIL.Image.Image image mode=RGB size=140x30 at 0x7FA82D0D4DD8>
# predicted label:  113163699 dataset label:  113162699
# <PIL.Image.Image image mode=RGB size=140x30 at 0x7FA82D0D4DD8>
# predicted label:  120644640 dataset label:  120644630
