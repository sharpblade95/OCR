# %% [markdown]
# <a href="https://colab.research.google.com/github/sharpblade95/OCR/blob/master/results.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
forward_pass()
# Out:
# Total accuracy on dataset:  0.8442
# Predicted with >90% confidence:  0.5629
# Predicted wrong with >90% confidence:  0.005652711535064477
#
# Mistake samples 90%:
# <PIL.Image.Image image mode=RGB size=140x30 at 0x7F97EEEEA7F0>
# predicted label:  1121898027 dataset label:  112189827 confidence :  0.933125552766287
# <PIL.Image.Image image mode=RGB size=140x30 at 0x7F97EE1E39B0>
# predicted label:  491084651 dataset label:  491082651 confidence :  0.9302670227556983
# <PIL.Image.Image image mode=RGB size=140x30 at 0x7F98074899E8>
# predicted label:  078303151 dataset label:  783031510 confidence :  0.9297744280202798
# <PIL.Image.Image image mode=RGB size=140x30 at 0x7F97EEEEAD30>
# predicted label:  532111127 dataset label:  532111137 confidence :  0.9382843533091194
# <PIL.Image.Image image mode=RGB size=140x30 at 0x7F97EEEEABE0>
# predicted label:  242181846 dataset label:  142181846 confidence :  0.9063049260351584
# <PIL.Image.Image image mode=RGB size=140x30 at 0x7F97EEEEAD30>
# predicted label:  213296324 dataset label:  213296322 confidence :  0.9373711319887049
# <PIL.Image.Image image mode=RGB size=140x30 at 0x7F97EEEEABE0>
# predicted label:  432827999 dataset label:  332827999 confidence :  0.9386302226988815
# <PIL.Image.Image image mode=RGB size=140x30 at 0x7F97EEEEAD30>
# predicted label:  452185246 dataset label:  452185746 confidence :  0.9036986134269858
# <PIL.Image.Image image mode=RGB size=140x30 at 0x7F97EEEEABE0>
# predicted label:  892179929 dataset label:  892179919 confidence :  0.941929784574601
# <PIL.Image.Image image mode=RGB size=140x30 at 0x7F97EEEEAD30>
# predicted label:  7821214943 dataset label:  782164943 confidence :  0.9203312902895251
# <PIL.Image.Image image mode=RGB size=140x30 at 0x7F97EEEEABE0>
# predicted label:  151916184 dataset label:  151916182 confidence :  0.9313750013668575
# <PIL.Image.Image image mode=RGB size=140x30 at 0x7F97EEEEAD30>
# predicted label:  243232311 dataset label:  241632311 confidence :  0.9155653942778467
# <PIL.Image.Image image mode=RGB size=140x30 at 0x7F97EEEEABE0>
# predicted label:  522196523 dataset label:  522196522 confidence :  0.9152037493682739
# <PIL.Image.Image image mode=RGB size=140x30 at 0x7F97EEEEAD30>
# predicted label:  113163699 dataset label:  113162699 confidence :  0.9502109680721172
# <PIL.Image.Image image mode=RGB size=140x30 at 0x7F97EEEEABE0>
# predicted label:  582715524 dataset label:  582715522 confidence :  0.9788240480744659
# <PIL.Image.Image image mode=RGB size=140x30 at 0x7F97EEEEAD30>
# predicted label:  412198217 dataset label:  412198117 confidence :  0.9233803611052205
# <PIL.Image.Image image mode=RGB size=140x30 at 0x7F97EEEEABE0>
# predicted label:  137276619 dataset label:  372766199 confidence :  0.9750048256535867
# <PIL.Image.Image image mode=RGB size=140x30 at 0x7F97EEEEAD30>
# predicted label:  2802711089 dataset label:  280271589 confidence :  0.9391825430607169
# <PIL.Image.Image image mode=RGB size=140x30 at 0x7F97EEEEABE0>
# predicted label:  970679278 dataset label:  970679378 confidence :  0.9392668190301092
# <PIL.Image.Image image mode=RGB size=140x30 at 0x7F97EEEEAD30>
# predicted label:  6327758227 dataset label:  632775820 confidence :  0.9242433198370512
# <PIL.Image.Image image mode=RGB size=140x30 at 0x7F97EEEEABE0>
# predicted label:  662471226 dataset label:  662471216 confidence :  0.9863296916518288
# <PIL.Image.Image image mode=RGB size=140x30 at 0x7F97EEEEAD30>
# predicted label:  332135155 dataset label:  322135155 confidence :  0.9363210165092493
# <PIL.Image.Image image mode=RGB size=140x30 at 0x7F97EEEEABE0>
# predicted label:  192843799 dataset label:  192823799 confidence :  0.9778462631155244
# <PIL.Image.Image image mode=RGB size=140x30 at 0x7F97EEEEAD30>
# predicted label:  762738126 dataset label:  762738116 confidence :  0.9275129568356996
# <PIL.Image.Image image mode=RGB size=140x30 at 0x7F97EEEEABE0>
# predicted label:  391016210 dataset label:  391016310 confidence :  0.9765120046946646
# <PIL.Image.Image image mode=RGB size=140x30 at 0x7F97EEEEAD30>
# predicted label:  382977425 dataset label:  382977225 confidence :  0.99285989529101
# <PIL.Image.Image image mode=RGB size=140x30 at 0x7F97EEEEABE0>
# predicted label:  270468624 dataset label:  270468622 confidence :  0.9341137376033727
# <PIL.Image.Image image mode=RGB size=140x30 at 0x7F97EEEEAD30>
# predicted label:  236219961 dataset label:  362199615 confidence :  0.9195496803701417
# <PIL.Image.Image image mode=RGB size=140x30 at 0x7F97EEEEABE0>
# predicted label:  442144317 dataset label:  442143317 confidence :  0.9478309491657676
# <PIL.Image.Image image mode=RGB size=140x30 at 0x7F97EEEEAD30>
# predicted label:  120644640 dataset label:  120644630 confidence :  0.9559090754360757
# <PIL.Image.Image image mode=RGB size=140x30 at 0x7F97EEEEABE0>
# predicted label:  443261777 dataset label:  243261777 confidence :  0.9793110259947276
# <PIL.Image.Image image mode=RGB size=140x30 at 0x7F97EEEEAF60>
# predicted label:  663157624 dataset label:  663157622 confidence :  0.9068235534567721
# Predicted with >95% confidence:  0.4304
# Predicted wrong with >95% confidence:  0.0020867145838163693
#
# Mistake samples 95%:
# <PIL.Image.Image image mode=RGB size=140x30 at 0x7F97EEEEAD30>
# predicted label:  113163699 dataset label:  113162699 confidence:  0.9502109680721172
# <PIL.Image.Image image mode=RGB size=140x30 at 0x7F97EEEEA9E8>
# predicted label:  582715524 dataset label:  582715522 confidence:  0.9788240480744659
# <PIL.Image.Image image mode=RGB size=140x30 at 0x7F97EEEEAD30>
# predicted label:  137276619 dataset label:  372766199 confidence:  0.9750048256535867
# <PIL.Image.Image image mode=RGB size=140x30 at 0x7F97EEEEA7F0>
# predicted label:  662471226 dataset label:  662471216 confidence:  0.9863296916518288
# <PIL.Image.Image image mode=RGB size=140x30 at 0x7F97EEEEAF60>
# predicted label:  192843799 dataset label:  192823799 confidence:  0.9778462631155244
# <PIL.Image.Image image mode=RGB size=140x30 at 0x7F97EEEEA9E8>
# predicted label:  391016210 dataset label:  391016310 confidence:  0.9765120046946646
# <PIL.Image.Image image mode=RGB size=140x30 at 0x7F97EEEEAD30>
# predicted label:  382977425 dataset label:  382977225 confidence:  0.99285989529101
# <PIL.Image.Image image mode=RGB size=140x30 at 0x7F97EEEEA9E8>
# predicted label:  120644640 dataset label:  120644630 confidence:  0.9559090754360757
# <PIL.Image.Image image mode=RGB size=140x30 at 0x7F97EEEEAD30>
# predicted label:  443261777 dataset label:  243261777 confidence:  0.9793110259947276
